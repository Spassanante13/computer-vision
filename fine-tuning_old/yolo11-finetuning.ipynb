# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !yolo train data=/kaggle/input/cv-project-yolo-finetuning/soccer-1/data.yaml model=yolo11m.pt epochs=75 imgsz=640
# Out:
# ...
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r runs.zip /kaggle/working/runs
# Out:
# updating: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/BoxPR_curve.png (deflated 13%)
#   adding: kaggle/working/runs/detect/train/BoxP_curve.png (deflated 11%)
#   adding: kaggle/working/runs/detect/train/train_batch0.jpg (deflated 2%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 24%)
#   adding: kaggle/working/runs/detect/train/train_batch28536.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train/val_batch1_labels.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train/weights/last.pt (deflated 8%)
# ...
